# %% [markdown]
# <a href="https://colab.research.google.com/github/zasaei/Articles_NTM/blob/main/basic_python_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Slide1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide2.JPG](data:image/jpeg;base64,...)

# %%
20 + 10
# Out:
# 30

# %%
20 - 10
# Out:
# 10

# %%
20 * 20
# Out:
# 400

# %%
20 / 10
# Out:
# 2.0

# %%
3 ** 3
# Out:
# 27

# %%
20 / (10+10)
# Out:
# 1.0

# %%
20 / 12 * 3 - 4 + 5
# Out:
# 6.0

# %%
40*5-2+6/5/4
# Out:
# 198.3

# %% [markdown]
# ![Slide3.JPG](data:image/jpeg;base64,...)

# %%
0.5 + 0.5
# Out:
# 1.0

# %%
0.5 - 0.5
# Out:
# 0.0

# %%
0.5 / 0.5
# Out:
# 1.0

# %%
0.5 * 0.5
# Out:
# 0.25

# %% [markdown]
# ![Slide5.JPG](data:image/jpeg;base64,...)

# %%
20 / 10
# Out:
# 2.0

# %%
1 + 2.0
# Out:
# 3.0

# %% [markdown]
# ![Slide6.JPG](data:image/jpeg;base64,...)

# %%
round((0.1 + 0.2),1)
# Out:
# 0.3

# %%
round(1.75)
# Out:
# 2

# %%
round(1.25 , 0)
# Out:
# 1.0

# %%
round(1.25,1)
# Out:
# 1.2

# %%
round(1.25434,3)
# Out:
# 1.254

# %% [markdown]
# ![Slide14.JPG](data:image/jpeg;base64,...)

# %%
count = 10_000_000_000
print(count)
# Out:
# 10000000000

# %%
#a = 25000000256416
a = 25_000_000_256_416
print(a)
# Out:
# 25000000256416

# %% [markdown]
# ![Slide15.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide16.JPG](data:image/jpeg;base64,...)

# %%
20 > 10
# Out:
# True

# %%
20 < 10
# Out:
# False

# %% [markdown]
# ![Slide17.JPG](data:image/jpeg;base64,...)

# %%
'a' < 'b'
# Out:
# True

# %%
'a' > 'b'
# Out:
# False

# %%
bool('Hi')
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
bool(100)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool('0')
# Out:
# True

# %%
bool(0.0)
# Out:
# False

# %% [markdown]
# ![Slide18.JPG](data:image/jpeg;base64,...)

# %%
bool(None)
# Out:
# False

# %%
bool([0])
# Out:
# True

# %%
bool((0))
# Out:
# False

# %%
bool({(0)})
# Out:
# True

# %% [markdown]
# ![Slide19.JPG](data:image/jpeg;base64,...)

# %%
NAME = "Smartech"

# %% [markdown]
# ![Slide20.JPG](data:image/jpeg;base64,...)

# %%
first_name = input('Please inter your first name:')
second_name = input('Inter second name:')

print(f'Welcome {first_name} {second_name} to smartech')
# Out:
# Please inter your first name:Ehsan
# Inter second name:Karimi
# Welcome Ehsan Karimi to smartech

# %% [markdown]
# ![Slide21.JPG](data:image/jpeg;base64,...)

# %%
price = input('Enter the price ($):')
tax = input('Enter the tax rate (%):')
net_price = price + (price * tax / 100)
print(f'The net price is $ {net_price}')
# Out:
# Enter the price ($):500
# Enter the tax rate (%):9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-cd2c134dfefc> in <cell line: 3>()
#       1 price = input('Enter the price ($):')
#       2 tax = input('Enter the tax rate (%):')
# ----> 3 net_price = price + (price * tax / 100)
#       4 print(f'The net price is $ {net_price}')
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
price = int(input('Enter the price ($):'))
tax = int(input('Enter the tax rate (%):'))
net_price = price + (price * tax / 100)
print(f'The net price is $ {net_price}')
# Out:
# Enter the price ($):5000
# Enter the tax rate (%):9
# The net price is $ 5450.0

# %% [markdown]
# ![Slide22.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide23.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![Slide24.JPG](data:image/jpeg;base64,...)

# %%
str(32)
# Out:
# '32'

# %%
bool(10)
# Out:
# True

# %%
str(15)
# Out:
# '15'

# %% [markdown]
# ![Slide25.JPG](data:image/jpeg;base64,...)

# %%
type(100)
# Out:
# int

# %%
type(0.2)
# Out:
# float

# %%
type("hello")
# Out:
# str

# %%
hello='hi'
type(hello)
# Out:
# str

# %%
type('True')
# Out:
# str

# %%
type(True)
# Out:
# bool

# %% [markdown]
# برنامه ای ایجاد کنید که به نام کاربر خوشامد بگوید.
#
# ```
# # This is formatted as code
# ```

# %%
name = input("What is your name? ")
print ("wellcome: {name}")
# Out:
# What is your name? z
# wellcome: {name}
